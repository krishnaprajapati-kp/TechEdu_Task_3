# %% [markdown]
# # Perform ‘Exploratory Data Analysis’ on dataset ‘Mallcustomers’
# --------------------------------------------------
# # Author:-Krishna Prajapati

# %%
## Importing the required libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
Mall_data=pd.read_csv(r"C:\Users\KRISHNA PRAJAPATI\Desktop\Techedu internship\Mall_Customers.csv")

# %%
Mall_data.head()
# Out:
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
Mall_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Genre                   200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB

# %%
## for continous data set
Mall_data.describe()
# Out:
#        CustomerID         Age  Annual Income (k$)  Spending Score (1-100)
# count  200.000000  200.000000          200.000000              200.000000
# mean   100.500000   38.850000           60.560000               50.200000
# std     57.879185   13.969007           26.264721               25.823522
# min      1.000000   18.000000           15.000000                1.000000
# 25%     50.750000   28.750000           41.500000               34.750000
# 50%    100.500000   36.000000           61.500000               50.000000
# 75%    150.250000   49.000000           78.000000               73.000000
# max    200.000000   70.000000          137.000000               99.000000

# %% [markdown]
# ## Finding a range of customers according to age group in Mall_customers.

# %%
plt.figure(figsize=(8,5))
sns.histplot(x="Age",data=Mall_data)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %%
sns.set_style("whitegrid")
plt.figure(figsize=(12,5))
sns.countplot("Age",data=Mall_data,hue="Genre")
# Out:
# <AxesSubplot:xlabel='Age', ylabel='count'>

# %% [markdown]
# ------------------------------------------------------------------------------------
# ### It can be clearly seen that  age group of Female 23,31,32,35,49  and age group of Male 19,32,48 are maximum in Mall_customers.

# %%
Mall_data.columns
# Out:
# Index(['CustomerID', 'Genre', 'Age', 'Annual Income (k$)',
#        'Spending Score (1-100)'],
#       dtype='object')

# %% [markdown]
# ## Relation between age and Spending Score and Annual Income

# %%
plt.figure(figsize=(12,5))
plt.scatter("Age","Spending Score (1-100)",data=Mall_data,c="Spending Score (1-100)",s=75)
plt.xlabel("Age")
plt.ylabel("Spending Score")
plt.legend()

# %%
plt.figure(figsize=(15,5))
sns.barplot("Age","Spending Score (1-100)",data=Mall_data,ci=None)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Spending Score (1-100)'>

# %% [markdown]
# ### From the above graph ,it can be seen that the age group between 18-40 having higher Spending Score upto 100 and the age group between 41 - 70 having  less Spending Score upto 60

# %%
plt.figure(figsize=(12,5))
plt.scatter("Age","Annual Income (k$)",data=Mall_data,c="Annual Income (k$)",s=75)
plt.xlabel("Age")
plt.ylabel("Annual Income (k$)")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.barplot("Age","Annual Income (k$)",data=Mall_data,ci=False)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Annual Income (k$)'>

# %% [markdown]
# ### From the above graph it can be seen that Age group between 28-41 having higher Annual Income upto 100(kdoller) and the remainig age group having Annual Income upto 80(k$)

# %% [markdown]
# -----------------------------------------------------------------------------------------------------

# %% [markdown]
# ##  Cluster of Annual Income (k) V/s Spending Score and obervation reading accordingly

# %%
plt.figure(figsize=(8,5))
plt.scatter("Annual Income (k$)","Spending Score (1-100)",data=Mall_data,c="Spending Score (1-100)",s=75)
plt.xlabel("Annual Income")
plt.ylabel("Spending Score")
plt.legend()
plt.show()

# %% [markdown]
# ### From the above graph it can be observed that no of cluster is 5

# %% [markdown]
# ### But lets verify it by Elbow method

# %%
#Training the Model by taking different no cluster ranging between 1 to 10 that will help us to find the Elbow point
from sklearn.cluster import KMeans
kmeans=[]
for i in range(1,20):
    KMNS=KMeans(n_clusters=i,random_state=0)
    KMNS.fit(Mall_data.iloc[:,3:4])
    kmeans.append(KMNS.inertia_)

# %%
#To find the Elbow point by plotting the trained model
plt.plot(range(1,20),kmeans,color="blue",marker="o")
plt.xlabel("No of Clusters")
plt.ylabel("Within Cluster Sum of Square")
plt.title("The Elbow Method")
plt.show()

# %% [markdown]
# ### Now it is clear that after 5 in the x_axis ,showing similar behavier .So no Cluster=5

# %%
plt.figure(figsize=(8,5))
plt.scatter("Annual Income (k$)","Spending Score (1-100)",data=Mall_data,c="Spending Score (1-100)",s=75)
plt.xlabel("Annual Income")
plt.ylabel("Spending Score")
plt.legend()
plt.show()

# %% [markdown]
# ### Now from the graph ,it is seen that Annual Income having between 20 to 40 (k doller) and 70 to 140(k doller) having their spending score 0 to 40 and 60 to 100 ,they don't have spending score between 40 to 60 .
# ### Whereas those having Annual Income 40 to 60(k doller) ,having spending score between 40 to 60.

# %% [markdown]
# ## Conclusion:

# %% [markdown]
# ##  Q1). Range of customers according to age group in Mall_customers
# ## Ans:-Age group of Female 23,31,32,35,49 and age group of Male 19,32,48 are maximum in Mall_customers.

# %% [markdown]
# ----------------------------------------------------------------------
# ## Q2).Relation between age and Spending Score and Annual Income
# ## Ans:- Age group between 18-40 having higher Spending Score upto 100 and the age group between 41 - 70 having less Spending Score upto 60,
# ## Age group between 28-41 having higher Annual Income upto 100(kdoller) and the remainig age group having Annual Income upto 80(k$)

# %% [markdown]
# -------------------------------------------------------------------
# ## Q3).Cluster of Annual Income (k) V/s Spending Score and obervation reading accordingly
# ## Ans:-Annual Income  between 20 to 40 (k doller) and 70 to 140(k doller) having their spending score 0 to 40 and 60 to 100 ,they don't have spending score between 40 to 60 .Whereas those having Annual Income 40 to 60(k doller) ,having spending score between 40 to 60.

# %% [markdown]
# -----------------------------------------------------
# # Thank you
